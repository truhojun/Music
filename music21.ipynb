# %%
# %%capture

# converts midi files to wav files into order to play them
print('installing fluidsynth...')
# !apt-get install fluidsynth > /dev/null
# !cp /usr/share/sounds/sf2/FluidR3_GM.sf2 ./font.sf2

from IPython.display import Image, Audio
from music21 import *

def play(x):
    filename = x.write('mid')
    # !fluidsynth -ni font.sf2 $filename -F $filename\.wav -r 16000 > /dev/null
    display(Audio(filename + '.wav'))

# %%
from music21 import *

stream1 = stream.Stream()
stream1.append(chord.Chord(['D3', 'F#4', 'A5']))
stream1.append(chord.Chord(['D3', 'F#4', 'A5']))
stream1.append(note.Note("B#"))
stream1.append(note.Note("F#"))
stream1.append(note.Note("B#5"))
stream1.append(note.Note("F#"))
stream1.append(note.Note("B#4"))
stream1.append(note.Note("F#"))
stream1.append(chord.Chord(['D3', 'F#4', 'A5']))
play(stream1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
